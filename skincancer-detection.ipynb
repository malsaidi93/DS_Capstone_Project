# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

 #checkpoint# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/resnet-weights/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1269.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/623.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/820.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1354.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/45.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/369.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1711.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1173.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1488.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/436.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1409.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/71.jpg
# ...

# %% [markdown]
# # Necessary Libraries

# %%
# %matplotlib inline
import os 
import gc
import time
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.metrics import accuracy_score

from PIL import Image

import tensorflow as tf
from tensorflow import keras
from keras.optimizers import Adam, SGD, RMSprop
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
from keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,TensorBoard, EarlyStopping, CSVLogger
from keras.applications.resnet50 import ResNet50,preprocess_input
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from sklearn.model_selection import train_test_split,KFold, cross_val_score, GridSearchCV
from keras.layers import Dense, Flatten, GlobalAveragePooling2D,BatchNormalization,Dropout,Conv2D,MaxPool2D

# ResNet Weights
resnet_weights = '../input/resnet-weights/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %% [markdown]
# # **Defining Folder Locations to Read Data**

# %%
benign_test = '../input/skin-cancer-malignant-vs-benign/test/benign'
malignant_test= '../input/skin-cancer-malignant-vs-benign/test/malignant'

benign_train = '../input/skin-cancer-malignant-vs-benign/train/benign'
malignant_train ='../input/skin-cancer-malignant-vs-benign/train/malignant'

# %% [markdown]
# **Define a method to read the data**

# %%
# Lambda function to open Images 

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Loading Training Data
ims_benign = [read(os.path.join(benign_train, filename)) for filename in os.listdir(benign_train)]

ims_malignant = [read(os.path.join(malignant_train, filename)) for filename in os.listdir(malignant_train)]

# Training Set X_benign_train and X_malignant_train

X_benign_train = np.array(ims_benign, dtype='uint8')

X_malignant_train = np.array(ims_malignant, dtype='uint8')

# %%
# Loading Testing Data 
ims_benign = [read(os.path.join(benign_test, filename)) for filename in os.listdir(benign_test)]

ims_malignant = [read(os.path.join(malignant_test, filename)) for filename in os.listdir(malignant_test)]

X_benign_test = np.array(ims_benign, dtype='uint8')

X_malignant_test = np.array(ims_malignant, dtype='uint8')

# %% [markdown]
# * **Create Labels for Data**
# * **Benign label 0**
# * **Malignant label 1**

# %%
benign_training_instances = X_benign_train.shape[0]
malignant_training_instances = X_malignant_train.shape[0]

print('Benign Training Instances = ', benign_training_instances)
print('Malignant Training Instances = ', malignant_training_instances)
# Out:
# Benign Training Instances =  1440
# Malignant Training Instances =  1197

# %% [markdown]
# * **y_benign will represent the labels for benign training set (0)**
# * **y_malignant to represent the labels for malignant training set (1)**

# %%
y_benign_train = np.zeros(X_benign_train.shape[0])
y_malignant_train = np.ones(X_malignant_train.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])

# %% [markdown]
# * **Merge the Training data (benign with malignant)**
# * **Merge the Testing data (benign with malignant)**

# %%
X_train = np.concatenate((X_benign_train, X_malignant_train), axis = 0)
y_train = np.concatenate((y_benign_train, y_malignant_train), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# %% [markdown]
# **Shuffle the Data**

# %%
# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
# Display first 15 images of moles, and how they are classified
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %% [markdown]
# # One hot encoding

# %%
y_train = to_categorical(y_train, num_classes= 2)
y_test = to_categorical(y_test, num_classes= 2)

# %%
y_train.shape

# %%
print(y_test.shape)
print(y_train.shape)
# Out:
# (660, 2)
# (2637, 2)

# %% [markdown]
# # Normalize X data

# %%
X_train = X_train/255.
X_test = X_test/255.

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (2637, 224, 224, 3)
# (660, 224, 224, 3)

# %%
# Data auguments
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

# datagen.fit(x_train)

# %%
resnet_base = ResNet50(weights=resnet_weights, include_top=False, input_shape=(224,224,3),pooling='avg',classes=2)

# %%
resnet_base.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_5[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
resnet = Sequential()

resnet.add(resnet_base)
resnet.add(Flatten())
resnet.add(Dropout(0.5))
resnet.add(Dense(2048, activation='relu'))
resnet.add(Dropout(0.5))
resnet.add(BatchNormalization())
resnet.add(Dense(256, activation='relu'))
resnet.add(Dropout(0.5))
resnet.add(BatchNormalization())
resnet.add(Dense(2, activation = 'softmax'))
resnet.summary()
#gc.collect()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               524544
# ...

# %%
for layer in resnet_base.layers[:]:
  layer.trainable = False

# %%
resnet.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               524544
# ...

# %%
gc.collect()
# Out:
# 20

# %%
del resnet
gc.collect()
# Out:
# 779

# %%
resnet.compile(optimizer=RMSprop(lr=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
callbacks_list = [ModelCheckpoint(
        filepath = 'resnet-finetune-model.h5',
        monitor = 'val_loss',
        save_best_only = True),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.1,
            patience=5,
            mode='min',
            min_lr=1e-8),
        CSVLogger(
            filename='resnet-finetune-model.csv',
            separator = ',',
            append = False)]

# %%
batch_size = 64
history = resnet.fit_generator(datagen.flow(X_train,y_train,batch_size=batch_size),validation_data=(X_test,y_test),
                             
                             epochs=5,
                             
                             callbacks=callbacks_list)
# Out:
# Epoch 1/5
# 42/42 [==============================] - 37s 871ms/step - loss: 1.0286 - accuracy: 0.5002 - val_loss: 0.7005 - val_accuracy: 0.4545
# Epoch 2/5
# 42/42 [==============================] - 33s 798ms/step - loss: 1.0122 - accuracy: 0.5006 - val_loss: 0.7055 - val_accuracy: 0.4545
# Epoch 3/5
# 42/42 [==============================] - 33s 777ms/step - loss: 0.9818 - accuracy: 0.4915 - val_loss: 0.7086 - val_accuracy: 0.4545
# Epoch 4/5
# 42/42 [==============================] - 32s 763ms/step - loss: 0.9571 - accuracy: 0.5150 - val_loss: 0.7031 - val_accuracy: 0.4545
# Epoch 5/5
# 42/42 [==============================] - 31s 740ms/step - loss: 0.9830 - accuracy: 0.5085 - val_loss: 0.7065 - val_accuracy: 0.4545

# %%
# Unfreeze resnet_base model 
#resnet_base.trainable = True
for layer in resnet_base.layers[:165]:
  layer.trainable = False
for layer in resnet_base.layers[165:]:
  layer.trainable = True

for i, layer in enumerate(resnet_base.layers):
  print(i, layer.name, layer.trainable)
# Out:
# 0 input_2 False
# 1 conv1_pad False
# 2 conv1_conv False
# 3 conv1_bn False
# 4 conv1_relu False
# 5 pool1_pad False
# 6 pool1_pool False
# 7 conv2_block1_1_conv False
# 8 conv2_block1_1_bn False
# 9 conv2_block1_1_relu False
# 10 conv2_block1_2_conv False
# 11 conv2_block1_2_bn False
# 12 conv2_block1_2_relu False
# 13 conv2_block1_0_conv False
# 14 conv2_block1_3_conv False
# 15 conv2_block1_0_bn False
# 16 conv2_block1_3_bn False
# 17 conv2_block1_add False
# 18 conv2_block1_out False
# 19 conv2_block2_1_conv False
# 20 conv2_block2_1_bn False
# 21 conv2_block2_1_relu False
# 22 conv2_block2_2_conv False
# 23 conv2_block2_2_bn False
# 24 conv2_block2_2_relu False
# 25 conv2_block2_3_conv False
# 26 conv2_block2_3_bn False
# 27 conv2_block2_add False
# 28 conv2_block2_out False
# 29 conv2_block3_1_conv False
# 30 conv2_block3_1_bn False
# 31 conv2_block3_1_relu False
# 32 conv2_block3_2_conv False
# 33 conv2_block3_2_bn False
# 34 conv2_block3_2_relu False
# ...

# %%
resnet.compile(optimizer=RMSprop(lr=1e-4),
              loss='categorical_crossentropy',
             metrics=['accuracy'])
resnet.summary()
gc.collect()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               524544
# ...

# %%
from time import time
print('Fit the model...')
t0 = time() #timing counter starts
print('The model has started learning...')
nepochs=50
batch_size=64
history=resnet.fit_generator(datagen.flow(X_train,y_train,batch_size=batch_size),validation_data=(X_test,y_test),
                  
                  epochs=nepochs,
                 
                  callbacks=callbacks_list)
print('Fit model took', int(time() - t0),'s') #time is calculated with the help of counter
# Out:
# Fit the model...
# The model has started learning...
# Epoch 1/50
# 42/42 [==============================] - 40s 953ms/step - loss: 0.6101 - accuracy: 0.7368 - val_loss: 1.9787 - val_accuracy: 0.4545
# Epoch 2/50
# 42/42 [==============================] - 38s 903ms/step - loss: 0.3973 - accuracy: 0.8305 - val_loss: 2.2102 - val_accuracy: 0.4545
# Epoch 3/50
# 42/42 [==============================] - 37s 881ms/step - loss: 0.3161 - accuracy: 0.8555 - val_loss: 4.7617 - val_accuracy: 0.4545
# Epoch 4/50
# 42/42 [==============================] - 38s 911ms/step - loss: 0.2518 - accuracy: 0.8878 - val_loss: 1.7701 - val_accuracy: 0.4545
# Epoch 5/50
# 42/42 [==============================] - 39s 933ms/step - loss: 0.2164 - accuracy: 0.9048 - val_loss: 1.8102 - val_accuracy: 0.5455
# Epoch 6/50
# 42/42 [==============================] - 41s 964ms/step - loss: 0.1811 - accuracy: 0.9276 - val_loss: 9.2519 - val_accuracy: 0.4545
# Epoch 7/50
# ...

# %%
tf.keras.utils.plot_model(
    resnet,
    to_file="resnet.png",
    show_shapes=True,
    #show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)

# %%
y_pred = resnet.predict(X_test)

# %%
gc.collect()
# Out:
# 1508

# %%
import json
with open('history.json', 'w') as f:
    json.dump(str(history.history), f)

# %%
history.history

# %%
history_df = pd.DataFrame(history.history)
history_df[['accuracy', 'val_accuracy']].plot()

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

# %%
accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
# Out:
# 0.8924242424242425

# %%
from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

	Additionally, the loss plot Figure__ shows loss going rapidly to 0 and val_loss fluctuating over the first 15 epochs then rapidly decreasing to a steady 0.57.
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[313  47]
#  [ 24 276]]

# %%
from sklearn.metrics import classification_report
classification_report( np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.76      0.92      0.83       360\n           1       0.87      0.64      0.74       300\n\n    accuracy                           0.79       660\n   macro avg       0.81      0.78      0.78       660\nweighted avg       0.81      0.79      0.79       660\n'

# %%
auc(false_positive_rate, true_positive_rate)
# Out:
# 0.8947222222222222

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve

roc_log = roc_auc_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

plt.close()

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(y_test)):
    if(np.argmax(y_test[i])==np.argmax(y_pred[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(y_test)):
    if(not np.argmax(y_test[i])==np.argmax(y_pred[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(y_pred[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()

# %%
resnet_json = resnet.to_json()

with open("resnet50_RMSprop.json", "w") as json_file:
    json_file.write(resnet_json)
    
# serialize weights to HDF5
resnet.save_weights("resnet_RMS.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
